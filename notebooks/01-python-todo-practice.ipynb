# %% [markdown]
# # 01 Python TODO Practice
#
# This notebook gives students short TODO-style tasks similar to what they may see in challenge notebooks.

# %% [markdown]
# ## Task 1: Variables
# Replace the TODO values and run the cell.

# %%
student_name = "TODO"
score = 0
print(student_name, score)

# %% [markdown]
# ## Task 2: Strings
# Update the message so it prints your name inside the sentence.

# %%
name = "TODO"
print(f"Hello, {name}. Welcome to Python practice.")

# %% [markdown]
# ## Task 3: Lists
# Update the list so it contains three skills you are practicing.

# %%
skills = ["TODO", "TODO", "TODO"]
for skill in skills:
    print(skill)

# %% [markdown]
# ## Task 4: Dictionaries
# Replace the TODO values and print the team color.

# %%
team = {
    "name": "TODO",
    "color": "TODO",
    "members": 3
}
print(team["color"])

# %% [markdown]
# ## Task 5: Nested data
# Print the captain name from the dictionary below.

# %%
squad = {"team": "Blue", "captain": {"name": "Ava", "grade": 10}}
# TODO: print the captain name

# %% [markdown]
# ## Task 6: Functions
# Complete the function so it returns a label based on the score.
# - 90 or more -> `high`
# - 70 to 89 -> `medium`
# - below 70 -> `low`

# %%
def classify_score(score):
    # TODO: complete the logic
    pass

print(classify_score(95))
print(classify_score(78))
print(classify_score(60))

# %% [markdown]
# ## Task 7: Fix one line only
# The next function almost works. Change only one line so it returns double the input.

# %%
def double_value(x):
    return x + 2

print(double_value(4))

# %% [markdown]
# ## Task 8: Lists of dictionaries
# Finish the loop so it prints each student's name and score.

# %%
records = [
    {"name": "Ava", "score": 91},
    {"name": "Luis", "score": 84},
    {"name": "Mia", "score": 76},
]

for record in records:
    # TODO: print the name and score
    pass

# %% [markdown]
# ## Task 9: Read the surrounding code
# Only change the TODO line below. Do not rename anything else.

# %%
team_name = "Blue Rockets"
members = 4

def team_summary(name, count):
    # TODO: return a string like 'Blue Rockets has 4 members.'
    pass

print(team_summary(team_name, members))

# %% [markdown]
# ## Reflection
# What felt easiest? What felt hardest? What did you have to debug?
