# %% [markdown]
# # 05 Mini Classic AI Challenge Practice
#
# This is a short mock classic AI practice notebook.
#
# ## Goal
# Use the sample sensor data to identify rows that may need review based on unusually high values.

# %%
import pandas as pd
df = pd.read_csv('data/practice_sensor_data.csv')
df.head()

# %% [markdown]
# ## Task 1
# Inspect the data and describe what each column appears to represent.

# %% [markdown]
# ## Task 2
# Create a simple rule-based flag.
# Mark a row for review if:
# - temperature >= 85 OR
# - vibration >= 0.90

# %%
# TODO: create a new column called needs_review

# %% [markdown]
# ## Task 3
# Show only the rows where `needs_review` is True.

# %%
# TODO

# %% [markdown]
# ## Task 4
# In plain language, explain why rule-based checks can be useful even before building a full model.
