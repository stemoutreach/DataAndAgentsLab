# %% [markdown]
# # 00 Notebook Basics Practice
#
# This notebook helps students learn the basic actions they will use over and over in Jupyter notebooks.
#
# ## Goals
# - run cells
# - edit values
# - read outputs
# - notice cell order
# - restart and rerun when needed

# %% [markdown]
# ## Task 1
# Run the next code cell. Then change `team_name` to your own team name and run it again.

# %%
team_name = "Sky Builders"
print(f"Welcome, {team_name}!")

# %% [markdown]
# ## Task 2
# Change `points` and `bonus`, then run the cell again. What changed?

# %%
points = 5
bonus = 2
total = points + bonus
print('Total points:', total)

# %% [markdown]
# ## Task 3
# Replace the TODO text with your favorite Python topic.

# %%
favorite_topic = "TODO: replace this text"
print("Favorite topic:", favorite_topic)

# %% [markdown]
# ## Task 4
# Run the next cell. Then answer: what happens if you run this cell before running the earlier `points` cell?

# %%
double_points = points * 2
print('Double points:', double_points)

# %% [markdown]
# ## Task 5
# Which of these is a code cell and which is a markdown cell?
# Write your answer in a markdown cell below.

# %% [markdown]
# Example markdown text: this cell explains something, but it does not execute Python.

# %%
print('This is a code cell because Python runs here.')

# %% [markdown]
# ## Task 6
# Break the next cell on purpose by removing one quote or parenthesis. Run it, read the error, then fix it.

# %%
message = 'Notebook practice is helping me learn.'
print(message)

# %% [markdown]
# ## Task 7
# Run the next cell, then change the variable value and rerun only this cell. What changed?

# %%
status = 'ready'
print('Current status:', status)

# %% [markdown]
# ## Task 8
# Restart the notebook kernel and rerun the notebook from the top. Which cells depend on earlier cells?

# %% [markdown]
# ## Reflection
# In your own words, answer these questions:
# 1. What does it mean to run a cell out of order?
# 2. When would you restart and rerun a notebook?
# 3. What is the difference between a markdown cell and a code cell?
