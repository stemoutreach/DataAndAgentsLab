# %% [markdown]
# # 06 Mini Agentic AI Challenge Practice
#
# This is a short mock agentic AI practice notebook.
#
# ## Goal
# Practice prompt structure, tool thinking, connected steps, and output evaluation.

# %% [markdown]
# ## Task 1: Prompt structure
# Write a prompt that includes:
# - role
# - task
# - constraints
# - output format
#
# Scenario: summarize a short equipment alert for a supervisor.

# %% [markdown]
# ## Task 2: Example comparison
# Read these two prompt openings:
#
# A. `Summarize this alert.`
#
# B. `You are a maintenance assistant. Summarize this alert for a shift supervisor in 1 sentence. Include machine ID, temperature, and whether review is needed.`
#
# Write 2-3 bullets explaining why B is stronger.

# %% [markdown]
# ## Task 3: Python function as a tool
# Complete the function so it returns a short alert summary.

# %%
def summarize_alert(machine_id, temperature, status):
    # TODO: return one short sentence
    pass

print(summarize_alert("M-102", 89.7, "review"))

# %% [markdown]
# ## Task 4: Connected steps
# Complete the two-step workflow.
# Step 1 creates a summary.
# Step 2 decides whether to escalate.

# %%
def summarize_alert(machine_id, temperature, status):
    return f"{machine_id} is at {temperature} and status is {status}."

def decide_escalation(summary_text):
    # TODO: return "escalate" if the summary suggests review, otherwise "monitor"
    pass

summary = summarize_alert("M-102", 89.7, "review")
action = decide_escalation(summary)

print(summary)
print(action)

# %% [markdown]
# ## Task 5: Output evaluation
# Pretend a system returned this output:
#
# `Machine issue maybe happened. Someone should probably look.`
#
# Write 2-3 bullets explaining what is weak about this output.

# %% [markdown]
# ## Task 6: Workflow thinking
# Write 3-5 bullet steps for a simple workflow:
# 1. read input
# 2. summarize the alert
# 3. decide whether to escalate
# 4. return the result

# %% [markdown]
# ## Reflection
# What information needs to be passed from one step to the next? Why does that matter?
