# %% [markdown]
# # 02 pandas Data Practice
#
# This notebook helps students practice loading and inspecting tabular data.
#
# The sample CSV is included in the repo under `data/practice_sensor_data.csv`.

# %%
import pandas as pd

# %% [markdown]
# ## Task 1
# Load the CSV file into a DataFrame named `df`.

# %%
# TODO: load the CSV
# Hint: "data/practice_sensor_data.csv"

# %% [markdown]
# ## Task 2
# Show the first five rows.

# %%
# TODO: display the first five rows

# %% [markdown]
# ## Task 3
# Print the column names.

# %%
# TODO: print the column names

# %% [markdown]
# ## Task 4
# Use `df.info()` to inspect the table. What types of columns do you see?

# %%
# TODO

# %% [markdown]
# ## Task 5
# Use `df.describe()` for the numeric columns.

# %%
# TODO

# %% [markdown]
# ## Task 6
# Select only these columns: `temperature`, `pressure`, `vibration`.

# %%
# TODO: create a smaller DataFrame called feature_df

# %% [markdown]
# ## Task 7
# Filter the rows where `status` is `review`.

# %%
# TODO: create a DataFrame called review_rows

# %% [markdown]
# ## Task 8
# Sort the data by `temperature` from highest to lowest.

# %%
# TODO

# %% [markdown]
# ## Task 9
# Check whether any values are missing.

# %%
# TODO

# %% [markdown]
# ## Task 10
# Filter rows where `temperature >= 85` and `shift == 'night'`.

# %%
# TODO

# %% [markdown]
# ## Reflection
# Which rows look most unusual, and why? What did you learn from sorting or filtering the table?
