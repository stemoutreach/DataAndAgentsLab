# %% [markdown]
# # 07 Debugging Practice
#
# This notebook gives you several intentional bugs to find and fix.
#
# ## Goal
# Practice reading errors, checking values, and fixing one problem at a time.

# %% [markdown]
# ## Bug 1: Syntax issue
# Run the next cell, read the error, and fix it.

# %%
message = 'Debugging helps me learn'
print(message

# %% [markdown]
# ## Bug 2: Name issue
# The function name is correct, but something inside the code is not. Fix it.

# %%
def double_score(score):
    return sorce * 2

print(double_score(5))

# %% [markdown]
# ## Bug 3: Wrong column name
# Load the data and fix the column reference.

# %%
import pandas as pd
df = pd.read_csv("data/practice_sensor_data.csv")
print(df["temperatur"].head())

# %% [markdown]
# ## Bug 4: Logic issue
# The code runs, but the result is wrong. Fix the logic.

# %%
def needs_review(temp, vibration):
    if temp >= 85 and vibration >= 0.90:
        return True
    return False

print(needs_review(90, 0.30))   # should this be True?
print(needs_review(70, 1.10))   # should this be True?

# %% [markdown]
# ## Bug 5: Notebook order issue
# This cell depends on a variable from another cell. What happens if you run it first?

# %%
total = points + bonus
print(total)

# %% [markdown]
# ## Bug 6: Type issue
# This code tries to combine a number and text. Fix it.

# %%
temperature = 88
message = "Temperature is " + temperature
print(message)

# %% [markdown]
# ## Reflection
# For each bug, write:
# - what kind of bug it was
# - how you found it
# - what you changed
# - one AI question you could ask if stuck
