# %% [markdown]
# # 04 AI-Assisted Problem Solving Practice
#
# This notebook helps students practice a healthy workflow for using AI while still thinking for themselves.

# %% [markdown]
# ## Scenario
# You are given starter code that is close to correct but not complete. Your job is to:
# 1. read the task
# 2. make a small change
# 3. test the result
# 4. optionally ask AI a focused question
# 5. explain what changed

# %% [markdown]
# ## Task 1
# Fix the function so it returns `review` when temperature is 85 or more. Otherwise return `normal`.

# %%
def check_temperature(temp):
    if temp > 100:
        return "review"
    return "normal"

print(check_temperature(72))
print(check_temperature(90))

# %% [markdown]
# ## Task 2
# Write down the exact question you would ask AI if you were stuck.
#
# Good example: `Why is my function returning normal for 90 when I want 85 or more to return review?`

# %% [markdown]
# ## Task 3
# Test these values after you fix the function:
# - 72
# - 85
# - 90

# %%
# Add your tests here

# %% [markdown]
# ## Task 4
# Fix the function below so it returns the larger of the two numbers.

# %%
def larger_value(a, b):
    if a < b:
        return a
    return b

print(larger_value(3, 9))
print(larger_value(8, 2))

# %% [markdown]
# ## Task 5
# Below is a weak AI answer. Write 2-3 bullet points explaining what is weak about it.
#
# > Just change the code and it should work. Maybe use a bigger number check.

# %% [markdown]
# ## Task 6
# Write a better AI question for the `larger_value` problem.

# %% [markdown]
# ## Task 7
# After fixing both functions, explain how you verified your results.

# %% [markdown]
# ## Reflection
# In 2-4 sentences, explain:
# - what was wrong
# - how you fixed it
# - how you verified the result
