# %% [markdown]
# # 10 Multi-Step Data Investigation
#
# This notebook gives you a more realistic connected data task.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/practice_sensor_data_large.csv")
df.head()

# %% [markdown]
# ## Task 1
# Inspect the dataset.
# - How many rows does it have?
# - What columns are present?
# - Are any values missing?

# %%
# TODO

# %% [markdown]
# ## Task 2
# Identify any suspicious values.
# Examples might include impossible temperatures, missing values, or misspelled shift labels.

# %%
# TODO

# %% [markdown]
# ## Task 3
# Create a cleaned DataFrame called `clean_df`.
# You decide what to clean first, but explain your choice.

# %%
# TODO

# %% [markdown]
# ## Task 4
# Create one chart that helps you inspect the cleaned data.

# %%
# TODO

# %% [markdown]
# ## Task 5
# Create a simple rule for flagging review-worthy rows.

# %%
# TODO

# %% [markdown]
# ## Task 6
# How many rows does your rule flag? Compare that with the original `status` column.

# %%
# TODO

# %% [markdown]
# ## Reflection
# Write 4-6 sentences summarizing:
# - what problems were in the dataset
# - what you cleaned
# - what your rule was
# - how well it matched the existing review labels
# - what you would improve next
