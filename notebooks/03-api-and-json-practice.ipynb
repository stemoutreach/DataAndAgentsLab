# %% [markdown]
# # 03 API and JSON Practice
#
# This notebook helps students practice reading JSON and preparing for API-based work.
#
# To keep this notebook dependable, it starts with sample JSON stored directly in the notebook. Then it shows an optional example using `requests`.

# %% [markdown]
# ## Part 1: Inspect sample JSON

# %%
sample_data = {
    "site": "Plant-7",
    "readings": [
        {"machine": "M-101", "temperature": 71.2, "status": "normal", "meta": {"shift": "day", "zone": "A"}},
        {"machine": "M-102", "temperature": 89.7, "status": "review", "meta": {"shift": "night", "zone": "B"}},
        {"machine": "M-103", "temperature": 73.4, "status": "normal", "meta": {"shift": "day", "zone": "A"}}
    ]
}

sample_data

# %% [markdown]
# ## Task 1
# Print the site name from `sample_data`.

# %%
# TODO

# %% [markdown]
# ## Task 2
# Print the status for machine `M-102`.

# %%
# TODO

# %% [markdown]
# ## Task 3
# Print the `zone` value for machine `M-102`.

# %%
# TODO

# %% [markdown]
# ## Task 4
# Create a small list that contains only `machine`, `temperature`, and `status` for each reading.

# %%
# TODO

# %% [markdown]
# ## Task 5
# Turn the `readings` list into a pandas DataFrame.

# %%
import pandas as pd
# TODO

# %% [markdown]
# ## Task 6
# Imagine one reading might be missing `meta`. Write 1-2 sentences explaining why checking structure first matters.

# %% [markdown]
# ## Optional: live API example
# The next cell shows what a real API call can look like. It may not run in all environments, but it is good practice to read it.

# %%
# Optional example
# import requests
# response = requests.get("https://api.github.com")
# print(response.status_code)
# api_data = response.json()
# list(api_data.keys())[:10]

# %% [markdown]
# ## Reflection
# Why is it useful to inspect JSON one small piece at a time?
