# %% [markdown]
# # 08 Plotting and Interpretation
#
# This notebook helps you create a few simple charts and explain what they show.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/practice_sensor_data_large.csv")
df.head()

# %% [markdown]
# ## Task 1
# Create a bar chart showing how many rows belong to each `shift` value.

# %%
# TODO

# %% [markdown]
# ## Task 2
# Create a histogram of `temperature`.
# Tip: you may want to ignore impossible values first.

# %%
# TODO

# %% [markdown]
# ## Task 3
# Create a scatter plot of `temperature` vs `vibration`.

# %%
# TODO

# %% [markdown]
# ## Task 4
# Write 2-4 sentences explaining what you notice in the charts.
# Consider:
# - unusual values
# - possible outliers
# - shift differences
# - suspicious points
