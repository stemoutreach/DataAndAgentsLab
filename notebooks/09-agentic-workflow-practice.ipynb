# %% [markdown]
# # 09 Agentic Workflow Practice
#
# This notebook gives you a simple agentic workflow using a mock LLM function so you can practice the workflow without needing a real API key.

# %% [markdown]
# ## Goal
# Practice prompt → model call → tool use → evaluate output → improve prompt.

# %%
def mock_llm(prompt):
    prompt_lower = prompt.lower()
    if "machine id" in prompt_lower and "temperature" in prompt_lower and "1 sentence" in prompt_lower:
        return "Machine M-102 is at 89.7 and needs review."
    if "summarize" in prompt_lower:
        return "Something may be wrong with the machine."
    return "I am not sure what format you want."

# %% [markdown]
# ## Task 1
# Run the two prompts below and compare the outputs.

# %%
weak_prompt = "Summarize this alert."
strong_prompt = "You are a maintenance assistant. Summarize this alert in 1 sentence. Include machine ID, temperature, and whether review is needed."

print("Weak output:", mock_llm(weak_prompt))
print("Strong output:", mock_llm(strong_prompt))

# %% [markdown]
# ## Task 2
# Write 2-3 bullet points explaining why the stronger prompt works better.

# %% [markdown]
# ## Task 3
# Complete the tool function so it formats a short alert record.

# %%
def build_alert_record(machine_id, temperature, status):
    # TODO: return a dictionary with these three fields
    pass

record = build_alert_record("M-102", 89.7, "review")
print(record)

# %% [markdown]
# ## Task 4
# Create a two-step workflow:
# 1. build the alert record
# 2. create a prompt from that record
# 3. send the prompt to the mock LLM

# %%
# TODO: use build_alert_record()
# TODO: create a prompt string
# TODO: call mock_llm(prompt)

# %% [markdown]
# ## Task 5
# Evaluate the output.
# Write 2-4 sentences on:
# - whether the output followed the instructions
# - what was missing if anything
# - how you would improve the prompt

# %% [markdown]
# ## Task 6
# Why is this still considered agentic or workflow-style even though the model is mocked?
